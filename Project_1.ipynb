# %% [markdown]
# #Personal Library Management System

# %% [markdown]
# <div class="markdown prose w-full break-words dark:prose-invert light"><p>Project Title: <strong>Personal Library Management System</strong></p><p><strong>Project Description:</strong>
# For this project, you will be building a Personal Library Management System using the Python programming concepts you've learned so far. This system will allow users to manage their personal book collection, add new books, remove books, search for books, and store information about each book.</p><p><strong>Project Requirements:</strong></p><ol><li><p><strong>Class Definitions:</strong></p><ul><li>Create a class named <code>Book</code> to represent a book with attributes like title, author, genre, and publication year.</li><li>Create a class named <code>Library</code> to represent the personal library. This class should have methods to add a book, remove a book, search for a book by title or author, and display the entire library.</li></ul></li><li><p><strong>Data Structure:</strong></p><ul><li>Use appropriate data structures like lists, dictionaries, or sets to store and manage the collection of books in the library.</li></ul></li><li><p><strong>File Handling:</strong></p><ul><li>Implement methods in the <code>Library</code> class to save and load the library data to/from a text or CSV file. This will ensure that the library data is persistent across different program executions.</li></ul></li><li><p><strong>Exception Handling:</strong></p><ul><li>Implement exception handling to handle potential errors gracefully. For instance, handle cases where a book is not found, a file is not found, or input validation errors occur.</li></ul></li><li><p><strong>User Interaction:</strong></p><ul><li>Create a user-friendly command-line interface that allows users to interact with the library. Provide options to add a book, remove a book, search for a book, and display the entire library.</li></ul></li></ol><p><strong>Project Steps:</strong></p><ol><li><p><strong>Class Definitions:</strong></p><ul><li>Define the <code>Book</code> class with appropriate attributes and a constructor.</li><li>Define the <code>Library</code> class with methods for adding, removing, searching, and displaying books.</li></ul></li><li><p><strong>Data Structure:</strong></p><ul><li>Initialize an empty data structure (list or dictionary) in the <code>Library</code> class to store the book objects.</li></ul></li><li><p><strong>File Handling:</strong></p><ul><li>Implement methods in the <code>Library</code> class to save the library data to a file (e.g., "library.txt" or "library.csv").</li><li>Implement methods to load the library data from the file during program startup.</li></ul></li><li><p><strong>Exception Handling:</strong></p><ul><li>Implement try-except blocks to handle errors related to user input, file operations, and book search.</li></ul></li><li><p><strong>User Interaction:</strong></p><ul><li>Create a user-friendly menu that presents options to the user (e.g., "Add a book," "Search for a book," etc.).</li><li>Based on the user's choice, call the appropriate methods in the <code>Library</code> class.</li></ul></li></ol><p><strong>Project Extensions:</strong>
# If you'd like to take this project further, consider adding the following features:</p><ul><li>Implement a graphical user interface (GUI) using a library like Tkinter or PyQt.</li><li>Allow users to rate and review books.</li><li>Sort and display books by different criteria (e.g., title, author, genre).</li><li>Provide recommendations based on the user's reading history.</li><li>Integrate an online book API to fetch book details automatically.</li></ul>
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
class Library :
  """This class can save and load the library data to/from a text or CSV file.
     and contain methods to add a book, remove a book,
     search for a book by title or author, and display the entire library"""
  title = []
  author = []
  genre = []
  publication_year = []
  Books = {'titles' : title, 'authors' : author, 'genres' : genre, 'publication_year' : publication_year}

  def __init__(self, File_name = '/content/drive/My Drive/my_library.txt') :  #used to load data from a file
    self.File_name = File_name
    try :
      with open(self.File_name, 'w+') as file :
        if File_name == '/content/drive/My Drive/my_library.txt' :
          pass
        else :
          Books = file.readline(self.File_name)
    except :
      raise Exception('invalid file path')

  def Add_Book(self, t, a = None, g = None, p = None) :
    self.title.append(t)
    self.author.append(a)
    self.genre.append(g)
    self.publication_year.append(p)

  def Remove_Book(self, t) :
    if t in self.Books['titles'] :                  #check if the book in the library or not
      i = self.Books['titles'].index(t)
      self.title.remove(t)
      del self.author[i]
      del self.genre[i]
      del self.publication_year[i]
      print(f'The book {t} removed successfully')
    else :
      print('The book is not in your library')

  def Search_For_Book(self, t = None, a = None) :
    if t != None :                                  #check if you send the book title
      flag = True if t in self.title else False
    elif a != None :                                #check if you send the book author
      flag = True if t in self.author else False
      i = self.Books['authors'].index(a)
      t = self.Books['titles'][i]
    else :
      print('Error !')

    if flag :                                      #if flag = 1
      print('The book was found and the book information is')
      print(Book(t))
    else :
      print('The book was not found')
    return flag

  def Display(self) :
    flag = 0
    if len(self.title) == 0 :                     #check if the library is embty or not
      print('Your library is embty')
      flag = 1
    else :
      for k, v in self.Books.items() : #that is not the correct method we can use pandas better
        print(f'{k} = {v}')
    return flag

  def Save_File(self) :
    with open(self.File_name, 'w') as file :
      for k, v in self.Books.items() :
        self.fl = file.write(f'{k} = {v}')
      print('Your file saved successfully')

class Book(Library) :
  """to represent a book with attributes like title, author, genre, and publication year"""
  def __init__(self, t) :                           #take the book title and give you all information about it
    i = self.Books['titles'].index(t)
    print(f'The book title is {super().title[i]}')
    print(f'The book author is {super().author[i]}')
    print(f'The book gerne is {super().genre[i]}')
    print(f'The book publication year is {super().publication_year[i]}')

#Start of our main code area
fl = input('Do you have a file ? y/n if y enter the file path otherwise enter n ')
if fl.lower() == 'n' :
  l = Library()
else :
  l = Library(fl)
  print('Create your library instead ')

while True :
  try :
    n = int(input("""Hello Please choose number :
                      1 : Add a book
                      2 : Remove a book
                      3 : Search for a book
                      4 : Display your library
                      5 : Save your library \n"""))

    if n == 1 :
      t = input('What is the book title ? ')
      a = input('What is the book author (optional) ? ')
      g = input('What is the book genre (optional) ? ')
      y = input('What is the book publication year (optional) ? ')
      l.Add_Book(t, a, g, y)

    elif n == 2 :
      f = l.Display()
      if not f :
        b = input('What is the title of the book you want to delete : ')
        l.Remove_Book(b)
      else :
        pass

    elif n == 3 :
      if len(l.title) != 0 :
        try :
          s = int(input('Choose : Do you want to search by 1: title or 2: author : '))
          if s == 1 :
            t = input('Please enter the book title : ')
            l.Search_For_Book(t)
          elif s == 2 :
            a = input('Please enter the book author : ')
            l.Search_For_Book(a)
          else :
            raise Exception('Wrong choice !')
        except :
          raise Exception('Please enter a number ')
      else :
        print('Your library is embty')

    elif n == 4 :
      l.Display()

    elif n == 5 :
      l.Save_File()

    else :
      raise Exception('Wrong choice !')

    f = input('Do you want onether thing ? y / n : ')
    if f.lower() == 'y' :
      continue
    elif f.lower() == 'n' :
      print('Thanks for using my program ^_^')
      break
    else :
      raise Exception('Wrong choice !')
  except ValueError :
    raise Exception('Please enter a number')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Do you have a file ? y/n if y enter the file path otherwise enter n n
# Hello Please choose number :
#                       1 : Add a book
#                       2 : Remove a book
#                       3 : Search for a book
#                       4 : Display your library
#                       5 : Save your library
# 1
# What is the book title ? Strong
# What is the book author (optional) ? me
# What is the book genre (optional) ? Nothing
# What is the book publication year (optional) ? 2023
# Do you want onether thing ? y / n : y
# Hello Please choose number :
#                       1 : Add a book
#                       2 : Remove a book
#                       3 : Search for a book
#                       4 : Display your library
#                       5 : Save your library
# 1
# What is the book title ? Shuggie Bain
# What is the book author (optional) ? Douglas Stuart
# What is the book genre (optional) ?
# What is the book publication year (optional) ? 1980
# Do you want onether thing ? y / n : y
# Hello Please choose number :
#                       1 : Add a book
#                       2 : Remove a book
#                       3 : Search for a book
#                       4 : Display your library
#                       5 : Save your library
# 1
# What is the book title ? The Line of Beauty
# What is the book author (optional) ? Alan Hollinghurst
# What is the book genre (optional) ? novel
# What is the book publication year (optional) ? 1985
# Do you want onether thing ? y / n : y
# Hello Please choose number :
#                       1 : Add a book
#                       2 : Remove a book
#                       3 : Search for a book
#                       4 : Display your library
#                       5 : Save your library
# 3
# Choose : Do you want to search by 1: title or 2: author : 1
# Please enter the book title : Strong
# The book was found and the book information is
# The book title is Strong
# The book author is me
# The book gerne is Nothing
# The book publication year is 2023
# <__main__.Book object at 0x7d210a8fc9a0>
# Do you want onether thing ? y / n : y
# Hello Please choose number :
#                       1 : Add a book
#                       2 : Remove a book
#                       3 : Search for a book
#                       4 : Display your library
#                       5 : Save your library
# 2
# titles = ['Strong', 'Shuggie Bain', 'The Line of Beauty']
# authors = ['me', 'Douglas Stuart', 'Alan Hollinghurst']
# genres = ['Nothing', '', 'novel']
# publication_year = ['2023', '1980', '1985']
# What is the title of the book you want to delete : Shuggie Bain
# The book Shuggie Bain removed successfully
# Do you want onether thing ? y / n : y
# Hello Please choose number :
#                       1 : Add a book
#                       2 : Remove a book
#                       3 : Search for a book
#                       4 : Display your library
#                       5 : Save your library
# 4
# titles = ['Strong', 'The Line of Beauty']
# authors = ['me', 'Alan Hollinghurst']
# genres = ['Nothing', 'novel']
# publication_year = ['2023', '1985']
# Do you want onether thing ? y / n : y
# Hello Please choose number :
#                       1 : Add a book
#                       2 : Remove a book
#                       3 : Search for a book
#                       4 : Display your library
#                       5 : Save your library
# 5
# Your file saved successfully
# Your file saved successfully
# Your file saved successfully
# Your file saved successfully
# Do you want onether thing ? y / n : n
# Thanks for using my program ^_^
